# %%
import pandas as pd

# %%
import pandas as pd
#series
series = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-total-female-births-CA.csv', header =0, parse_dates=  [0], index_col = 0, squeeze= True)
series.head()
print(series['1959'])
#dataframe
df2 = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-total-female-births-CA.csv', header =0, parse_dates=  [0] )
df2[(df2['date'] > '1959-01-01') & (df2['date'] <= '1959-01-31')]
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
#               ..
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: births, Length: 365, dtype: int64
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34
# 21 1959-01-22      53
# 22 1959-01-23      39
# 23 1959-01-24      32
# 24 1959-01-25      37
# 25 1959-01-26      43
# 26 1959-01-27      39
# 27 1959-01-28      35
# 28 1959-01-29      44
# 29 1959-01-30      38
# ...

# %%
dataframe = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-total-female-births-CA.csv', header =0 )

# %%
dataframe.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
dataframe['date'].dtype
# Out:
# dtype('O')

# %%
df2 = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-total-female-births-CA.csv', header =0, parse_dates=  [0] )

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df2['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
series = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-total-female-births-CA.csv', header =0, parse_dates=  [0], index_col = 0, squeeze= True)

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
print(series['1959'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
#               ..
# 1959-12-27    37
# 1959-12-28    52
# 1959-12-29    48
# 1959-12-30    55
# 1959-12-31    50
# Name: births, Length: 365, dtype: int64

# %%
df2[(df2['date'] > '1959-01-01') & (df2['date'] <= '1959-01-31')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34
# 21 1959-01-22      53
# 22 1959-01-23      39
# 23 1959-01-24      32
# 24 1959-01-25      37
# 25 1959-01-26      43
# 26 1959-01-27      39
# 27 1959-01-28      35
# 28 1959-01-29      44
# 29 1959-01-30      38
# 30 1959-01-31      24

# %%
series.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: births, dtype: float64

# %%
df2.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
Dataviz_df = df2.copy()

# %%
Dataviz_df.head(10)
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44
# 5 1959-01-06      29
# 6 1959-01-07      45
# 7 1959-01-08      43
# 8 1959-01-09      38
# 9 1959-01-10      27

# %%
Dataviz_df['births'].plot()
# Out:
# <AxesSubplot:>

# %%
Dataviz_df.index = Dataviz_df['date']

# %%
Dataviz_df['births'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
Dataviz_df2 = Dataviz_df[(Dataviz_df['date']> '1959-01-01') & (Dataviz_df['date']<='1959-01-10')].copy()

# %%
Dataviz_df2
# Out:
#                  date  births
# date
# 1959-01-02 1959-01-02      32
# 1959-01-03 1959-01-03      30
# 1959-01-04 1959-01-04      31
# 1959-01-05 1959-01-05      44
# 1959-01-06 1959-01-06      29
# 1959-01-07 1959-01-07      45
# 1959-01-08 1959-01-08      43
# 1959-01-09 1959-01-09      38
# 1959-01-10 1959-01-10      27

# %%
Dataviz_df2['births'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import seaborn as sns

# %%
sns.regplot(x = df2.index.values, y = df2['births'])
# Out:
# <AxesSubplot:ylabel='births'>

# %%
sns.regplot(x= df2.index.values, y = df2['births'], order =5)
# Out:
# <AxesSubplot:ylabel='births'>

# %%
miles_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/us-airlines-monthly-aircraft-miles-flown.csv', header =0, parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
import pandas as pd
#series
miles_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/us-airlines-monthly-aircraft-miles-flown.csv', header =0, parse_dates=[0])
from matplotlib import pyplot as plt
# %matplotlib inline
miles_df['MilesMM'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x= miles_df.index.values, y = miles_df['MilesMM'])
# Out:
# <AxesSubplot:ylabel='MilesMM'>

# %%
miles_df['year'] = miles_df['Month'].dt.year
miles_df.head()
miles_df.groupby('year')['MilesMM'].mean()
miles_df.groupby('year')['MilesMM'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
miles_df['lag1'] = miles_df['MilesMM'].shift(1)
import seaborn as sns
miles_df.head()
sns.scatterplot(x = miles_df['lag1'], y = miles_df['MilesMM'])
# Out:
# <AxesSubplot:xlabel='lag1', ylabel='MilesMM'>

# %%
#Method1

#Method 2
from pandas.plotting import lag_plot
lag_plot(miles_df['MilesMM'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(miles_df['MilesMM'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
df2.head(5)
features= df2.copy() 
features['year'] = df2['date'].dt.year
features['month'] = df2['date'].dt.month
features['day'] = df2['date'].dt.day
features.head(5)
# Out:
#         date  births  year  month  day
# 0 1959-01-01      35  1959      1    1
# 1 1959-01-02      32  1959      1    2
# 2 1959-01-03      30  1959      1    3
# 3 1959-01-04      31  1959      1    4
# 4 1959-01-05      44  1959      1    5

# %%
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
features['lag1'] = df2['births'].shift(1)
features['lag365'] = df2['births'].shift(365)
features.head(5)
# Out:
#         date  births  year  month  day  lag1  lag365
# 0 1959-01-01      35  1959      1    1   NaN     NaN
# 1 1959-01-02      32  1959      1    2  35.0     NaN
# 2 1959-01-03      30  1959      1    3  32.0     NaN
# 3 1959-01-04      31  1959      1    4  30.0     NaN
# 4 1959-01-05      44  1959      1    5  31.0     NaN

# %%
features['Roll_mean'] = df2['births'].rolling(window = 2).mean()
features.head(5)
features['Roll_max'] = df2['births'].rolling(window = 3).max()
features.head(5)
# Out:
#         date  births  year  month  day  lag1  lag365  Roll_mean  Roll_max
# 0 1959-01-01      35  1959      1    1   NaN     NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0     NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0     NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0     NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0     NaN       37.5      44.0

# %%
features['Exp_max'] = df2['births'].expanding().max()
features.head(10)
# Out:
#         date  births  year  month  day  lag1  lag365  Roll_mean  Roll_max  \
# 0 1959-01-01      35  1959      1    1   NaN     NaN        NaN       NaN
# 1 1959-01-02      32  1959      1    2  35.0     NaN       33.5       NaN
# 2 1959-01-03      30  1959      1    3  32.0     NaN       31.0      35.0
# 3 1959-01-04      31  1959      1    4  30.0     NaN       30.5      32.0
# 4 1959-01-05      44  1959      1    5  31.0     NaN       37.5      44.0
# 5 1959-01-06      29  1959      1    6  44.0     NaN       36.5      44.0
# 6 1959-01-07      45  1959      1    7  29.0     NaN       37.0      45.0
# 7 1959-01-08      43  1959      1    8  45.0     NaN       44.0      45.0
# 8 1959-01-09      38  1959      1    9  43.0     NaN       40.5      45.0
# 9 1959-01-10      27  1959      1   10  38.0     NaN       32.5      43.0
#
#    Exp_max
# 0     35.0
# 1     35.0
# 2     35.0
# 3     35.0
# 4     44.0
# 5     44.0
# 6     45.0
# 7     45.0
# 8     45.0
# 9     45.0

# %%
quaterly_mile_df = miles_df.resample('Q', on ='Month').mean()
quaterly_mile_df.head()
yearly_total_miles_df = miles_df.resample('A', on ='Month').sum()
yearly_total_miles_df.head()
# Out:
#             MilesMM   year      lag1
# Month
# 1963-12-31    99603  23556   92576.0
# 1964-12-31   106192  23568  105617.0
# 1965-12-31   115431  23580  115100.0
# 1966-12-31   119154  23592  117807.0
# 1967-12-31   126515  23604  126181.0

# %%
quaterly_mile_df.head()
# Out:
#                  MilesMM    year          lag1
# Month
# 1963-03-31   6696.333333  1963.0   6502.500000
# 1963-06-30   8756.000000  1963.0   7902.666667
# 1963-09-30  10392.333333  1963.0  10286.000000
# 1963-12-31   7356.333333  1963.0   8335.000000
# 1964-03-31   7287.666667  1964.0   7023.666667

# %%
upsampled_mile_df = miles_df.resample('D', on ='Month').mean()
interpolated_miles_df = upsampled_mile_df.interpolate(method = 'linear')
interpolated_miles_df.head(35)
# Out:
#                 MilesMM    year         lag1
# Month
# 1963-01-01  6827.000000  1963.0          NaN
# 1963-01-02  6806.064516  1963.0          NaN
# 1963-01-03  6785.129032  1963.0          NaN
# 1963-01-04  6764.193548  1963.0          NaN
# 1963-01-05  6743.258065  1963.0          NaN
# 1963-01-06  6722.322581  1963.0          NaN
# 1963-01-07  6701.387097  1963.0          NaN
# 1963-01-08  6680.451613  1963.0          NaN
# 1963-01-09  6659.516129  1963.0          NaN
# 1963-01-10  6638.580645  1963.0          NaN
# 1963-01-11  6617.645161  1963.0          NaN
# 1963-01-12  6596.709677  1963.0          NaN
# 1963-01-13  6575.774194  1963.0          NaN
# 1963-01-14  6554.838710  1963.0          NaN
# 1963-01-15  6533.903226  1963.0          NaN
# 1963-01-16  6512.967742  1963.0          NaN
# 1963-01-17  6492.032258  1963.0          NaN
# 1963-01-18  6471.096774  1963.0          NaN
# 1963-01-19  6450.161290  1963.0          NaN
# 1963-01-20  6429.225806  1963.0          NaN
# ...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
miles_decomp_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/us-airlines-monthly-aircraft-miles-flown.csv', header =0, parse_dates=[0])

# %%
miles_decomp_df.head()
# Out:
#                 Month  MilesMM
# Month
# 1963-01-01 1963-01-01     6827
# 1963-02-01 1963-02-01     6178
# 1963-03-01 1963-03-01     7084
# 1963-04-01 1963-04-01     8162
# 1963-05-01 1963-05-01     8462

# %%
miles_decomp_df.index = miles_decomp_df['Month']

# %%
result = seasonal_decompose(miles_decomp_df['MilesMM'], model= 'additive')

# %%
result.plot()

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
miles_decomp_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/us-airlines-monthly-aircraft-miles-flown.csv', header =0, parse_dates=[0])
miles_decomp_df.head()
miles_decomp_df.index = miles_decomp_df['Month']
result = seasonal_decompose(miles_decomp_df['MilesMM'], model= 'miltiplicative')
result.plot()

# %%
miles_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/us-airlines-monthly-aircraft-miles-flown.csv', header =0, parse_dates=[0])

# %%
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
miles_df['lag1'] = miles_df['MilesMM'].shift(1)

# %%
miles_df['MilesMM_diff1'] = miles_df['MilesMM'].diff(periods = 1)

# %%
miles_df.head()
# Out:
#        Month  MilesMM    lag1  MilesMM_diff1
# 0 1963-01-01     6827     NaN            NaN
# 1 1963-02-01     6178  6827.0         -649.0
# 2 1963-03-01     7084  6178.0          906.0
# 3 1963-04-01     8162  7084.0         1078.0
# 4 1963-05-01     8462  8162.0          300.0

# %%
miles_df.index = miles_df['Month']
result_a = seasonal_decompose(miles_df['MilesMM'], model='additive')
result_a.plot()

# %%
miles_df.index = miles_df['Month']
result_b = seasonal_decompose(miles_df.iloc[1:,3], model='additive')# 0th row is not selectted
result_b.plot()

# %%
miles_df['MilesMM'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
miles_df['MilesMM_diff1'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
miles_df['MilesMM_diff_12']= miles_df['MilesMM_diff1'].diff(periods=12)

# %%
miles_df['MilesMM_diff_12'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
result_c = seasonal_decompose(miles_df.iloc[13:,4], model = 'additive')
result_c.plot()

# %%
temp_df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-min-temperatures.csv', header =0, parse_dates=[0])

# %%
temp_df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
train_size = int(temp_df.shape[0] * 0.8)

# %% [raw]
# train_size

# %%
train = temp_df[0:train_size]

# %%
test  = temp_df[train_size:]

# %%
train.shape
# Out:
# (2920, 2)

# %%
test.shape
# Out:
# (730, 2)

# %%
df = pd.read_csv('C:/Users/Specter/Desktop/resources/Data Files/7. ST Academy - Time Series resource files/daily-min-temperatures.csv', header =0, parse_dates=[0])

# %%
df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
df['t']= df['Temp'].shift(1)

# %%
df.head(15)
# Out:
#          Date  Temp     t
# 0  1981-01-01  20.7   NaN
# 1  1981-01-02  17.9  20.7
# 2  1981-01-03  18.8  17.9
# 3  1981-01-04  14.6  18.8
# 4  1981-01-05  15.8  14.6
# 5  1981-01-06  15.8  15.8
# 6  1981-01-07  15.8  15.8
# 7  1981-01-08  17.4  15.8
# 8  1981-01-09  21.8  17.4
# 9  1981-01-10  20.0  21.8
# 10 1981-01-11  16.2  20.0
# 11 1981-01-12  13.3  16.2
# 12 1981-01-13  16.7  13.3
# 13 1981-01-14  21.5  16.7
# 14 1981-01-15  25.0  21.5

# %%
train, test = df[1:df.shape[0]-7], df[df.shape[0]-7:]

# %%
train.head()
# Out:
#         Date  Temp     t
# 1 1981-01-02  17.9  20.7
# 2 1981-01-03  18.8  17.9
# 3 1981-01-04  14.6  18.8
# 4 1981-01-05  15.8  14.6
# 5 1981-01-06  15.8  15.8

# %%
train_X, train_y = train['t'], train['Temp']
test_X, test_y = test['t'], test['Temp']

# %%
predictions = test_X.copy()

# %%
print(predictions)
# Out:
# 3643    10.0
# 3644    12.9
# 3645    14.6
# 3646    14.0
# 3647    13.6
# 3648    13.5
# 3649    15.7
# Name: t, dtype: float64

# %%
print(test_y)
# Out:
# 3643    12.9
# 3644    14.6
# 3645    14.0
# 3646    13.6
# 3647    13.5
# 3648    15.7
# 3649    13.0
# Name: Temp, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test_y, predictions)
mse
# Out:
# 3.4228571428571413

# %%
from matplotlib import pyplot

# %%
pyplot.plot(test_y)
pyplot.plot(predictions, color = 'red')
